# %%
# !pip install duckdb
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (1.3.2)

# %%
import duckdb

# %%
con = duckdb.connect(database=':memory:', read_only=False)

# %%
query = "SELECT * FROM 'customers.csv'"

# %%
result = con.execute(query).fetchdf()

# %%
result.head()
# Out:
#    customer_id first_name last_name                        email  \
# 0         1001       John       Doe         john.doe@example.com
# 1         1002      Emily     Smith    emily.smith@example.co.uk
# 2         1003    Michael     Brown    michael.brown@example.com
# 3         1004     Sophia    Wilson  sophia.wilson@example.co.th
# 4         1005      David   Johnson    david.johnson@example.com
#
#            created_at created_date  status country
# 0 2024-01-15 08:23:45   2024-01-15  active      US
# 1 2024-02-10 14:12:30   2024-02-10  active      UK
# 2 2024-03-05 19:45:12   2024-03-05  active      US
# 3 2024-04-01 09:05:55   2024-04-01  active      TH
# 4 2024-06-20 11:30:00   2024-06-20  active      US

# %%
result.shape
# Out:
# (10, 8)

# %%
filename = "Titanic-Dataset.csv"

# %%
query = f"SELECT * FROM '{filename}'"

# %%
df = con.execute(query).fetchdf()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  None        S

# %%
import seaborn as sns

titanic_result = sns.load_dataset("titanic")
titanic_result.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_result.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_result.shape
# Out:
# (891, 15)

# %%
titanic_result.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
query = "Select = * from_json_auto('products.json')"

# %%
print(query)
# Out:
# Select = * from_json_auto('products.json')

# %%
import duckdb

# สร้าง connection (หรือใช้ con ที่มีอยู่แล้ว)
con = duckdb.connect()

# รัน SQL อ่านไฟล์ JSON
result = con.execute("SELECT * FROM read_json_auto('products.json');").fetchdf()

# ดูข้อมูล 5 แถวแรก
print(result.head())
# Out:
#    id        name  price     category  in_stock
# 0   1      Laptop  35000  Electronics      True
# 1   2       Phone  18000  Electronics     False
# 2   3  Desk Chair   4500    Furniture      True

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        3 non-null      int64
#  1   name      3 non-null      object
#  2   price     3 non-null      int64
#  3   category  3 non-null      object
#  4   in_stock  3 non-null      bool
# dtypes: bool(1), int64(2), object(2)
# memory usage: 231.0+ bytes

# %%
result["price"].mean()
# Out:
# np.float64(19166.666666666668)

# %%
result[result["in_stock"] == True]
# Out:
#    id        name  price     category  in_stock
# 0   1      Laptop  35000  Electronics      True
# 2   3  Desk Chair   4500    Furniture      True

# %%
result.groupby("category")["price"].mean()
# Out:
# category
# Electronics    26500.0
# Furniture       4500.0
# Name: price, dtype: float64

# %%
query = """
SELECT
  customer_id,
  first_name,
  last_name,
  email,
  country,
  created_date
FROM 'customers.csv'
WHERE status = 'active'
  AND created_date >= '2024-01-01'
  AND country IN ('TH');
"""

thai_customers = con.execute(query).fetchdf()

# %%
query = """
SELECT
    PassengerId,
    Name,
    Age,
    Fare,
    CASE
        WHEN Survived = 1 THEN 'Survived'
        ELSE 'Not Survived'
    END as SurvivalStatus
FROM 'Titanic-Dataset.csv'
"""

transformed_data = con.execute(query).fetchdf()

# %%
query = """
SELECT
    c.customer_id,
    c.customer_name,
    c.segment,
    COUNT(DISTINCT o.order_id) as order_count,
    SUM(o.amount) as total_revenue,
    AVG(o.amount) as avg_order_value
FROM new_customers.csv c
LEFT JOIN orders.csv o
    ON c.customer_id = o.customer_id
    AND o.status != 'cancelled'
WHERE c.is_active = true
GROUP BY 1, 2, 3
"""

customer_metrics = con.execute(query).fetchdf()

# %%
query ="select from 'odders.csv'"

# %%
query = "SELECT * FROM read_csv_auto('orders.csv');"
orders_result = con.execute(query).fetchdf()
orders_result.head()
# Out:
#   order_id customer_id  amount order_date     status
# 0    O1001        C001   120.5 2024-01-15  completed
# 1    O1002        C001    75.0 2024-02-20  completed
# 2    O1003        C001    50.0 2024-03-05  cancelled
# 3    O1004        C002   200.0 2024-04-25  completed
# 4    O1005        C002   150.0 2024-05-01  completed

# %%
query = "SELECT * FROM read_csv_auto('orders.csv');"
orders_result = con.execute(query).fetchdf()
orders_result.head()
# Out:
#   order_id customer_id  amount order_date     status
# 0    O1001        C001   120.5 2024-01-15  completed
# 1    O1002        C001    75.0 2024-02-20  completed
# 2    O1003        C001    50.0 2024-03-05  cancelled
# 3    O1004        C002   200.0 2024-04-25  completed
# 4    O1005        C002   150.0 2024-05-01  completed

# %%
query = "select * from 'orders.csv'"
order_result = con.execute(query).fetchdf()
order_result.columns
# Out:
# Index(['order_id', 'customer_id', 'amount', 'order_date', 'status'], dtype='object')

# %%
query = "select * from 'new_customers.csv'"
costmer_result2 = con.execute(query).fetchdf()
costmer_result2.columns
# Out:
# Index(['customer_id', 'customer_name', 'segment', 'is_active'], dtype='object')

# %%
query = """
SELECT
    c.customer_id,
    c.customer_name,
    c.segment,
    COUNT(DISTINCT o.order_id) as order_count,
    SUM(o.amount) as total_revenue,
    AVG(o.amount) as avg_order_value
FROM new_customers.csv c
LEFT JOIN orders.csv o
    ON c.customer_id = o.customer_id
    AND o.status != 'cancelled'
WHERE c.is_active = true
GROUP BY 1, 2, 3
"""

customer_metrics = con.execute(query).fetchdf()

# %%
customer_metric =con.execute(query).fetchdf()

# %%
customer_metric.head()
# Out:
#   customer_id customer_name     segment  order_count  total_revenue  \
# 0        C002    Jane Smith   Corporate            2          350.0
# 1        C003     Acme Corp         SMB            1           80.0
# 2        C010     Small Biz         SMB            1           45.0
# 3        C001      John Doe    Consumer            2          195.5
# 4        C005    Global LLC  Enterprise            2          800.0
#
#    avg_order_value
# 0           175.00
# 1            80.00
# 2            45.00
# 3            97.75
# 4           400.00

# %%
# ถ้าต้องการหายอดรวมต่อ customer_id
query = """
SELECT customer_id, SUM(amount) AS total_amount
FROM read_csv_auto('orders.csv')
GROUP BY customer_id;
"""

result = con.execute(query).fetchdf()
result.head()
# Out:
#   customer_id  total_amount
# 0        C001         245.5
# 1        C002         350.0
# 2        C005         800.0
# 3        C007         100.0
# 4        C009        1000.0

# %%
query = """
SELECT customer_id, SUM(amount) AS total_amount
FROM read_csv_auto('orders.csv')
GROUP BY customer_id
"""
result = con.execute(query).fetchdf()
result.head()
# Out:
#   customer_id  total_amount
# 0        C001         245.5
# 1        C002         350.0
# 2        C005         800.0
# 3        C007         100.0
# 4        C009        1000.0

# %%
result = con.execute(query).fetchdf()

# %%
result2 = con.execute(query).fetchdf()

# %%
result2.head()
# Out:
#   customer_id  total_amount
# 0        C001         245.5
# 1        C002         350.0
# 2        C005         800.0
# 3        C007         100.0
# 4        C009        1000.0

# %%
query = """
WITH
-- ขั้นที่ 1: ดึงลูกค้าที่ active
active_customers AS (
    SELECT
        customer_id,
        customer_name,
        segment
    FROM new_customers.csv
    WHERE is_active = true
),

-- ขั้นที่ 2: คำนวณยอดสั่งซื้อ
order_metrics AS (
    SELECT
        customer_id,
        COUNT(*) as order_count,
        SUM(amount) as total_spent,
        AVG(amount) as avg_order_value
    FROM orders.csv
    WHERE order_date >= date_add(CURRENT_DATE, INTERVAL '-12 month')
    GROUP BY customer_id
),

-- ขั้นที่ 3: รวมข้อมูล
final AS (
    SELECT
        ac.*,
        COALESCE(om.order_count, 0) as orders_last_12m,
        COALESCE(om.total_spent, 0) as revenue_last_12m,
        om.avg_order_value
    FROM active_customers ac
    LEFT JOIN order_metrics om
        ON ac.customer_id = om.customer_id
)

SELECT * FROM final;
"""

result = con.execute(query).fetchdf()

# %%
result2 = con.execute(query).fetchdf()

# %%
result2.head()
# Out:
#   customer_id   customer_name     segment  orders_last_12m  revenue_last_12m  \
# 0        C007  Cancelled Cust    Consumer                1             100.0
# 1        C009    Future Buyer  Enterprise                1            1000.0
# 2        C010       Small Biz         SMB                1              45.0
# 3        C001        John Doe    Consumer                0               0.0
# 4        C002      Jane Smith   Corporate                0               0.0
#
#    avg_order_value
# 0            100.0
# 1           1000.0
# 2             45.0
# 3              NaN
# 4              NaN

# %%
query = """
WITH enriched_orders AS (
    SELECT
        o.*,
        c.customer_name,
        c.segment
    FROM orders.csv o
    LEFT JOIN new_customers.csv c
        ON o.customer_id = c.customer_id
)
SELECT
    order_id,
    customer_id,
    customer_name,
    order_date,
    amount,

    -- 1. ลำดับของ order ของลูกค้าแต่ละคน
    ROW_NUMBER() OVER (
        PARTITION BY customer_id
        ORDER BY order_date
    ) as order_sequence,

    -- 2. อันดับยอดขายในเดือนนั้น
    RANK() OVER (
        PARTITION BY strftime('%Y-%m', order_date)
        ORDER BY amount DESC
    ) as monthly_sales_rank,

    -- 3. ยอดสะสมของลูกค้า
    SUM(amount) OVER (
        PARTITION BY customer_id
        ORDER BY order_date
    ) as running_total,

    -- 4. ค่าเฉลี่ยเคลื่อนที่ 4 orders
    AVG(amount) OVER (
        PARTITION BY customer_id
        ORDER BY order_date
        ROWS BETWEEN 3 PRECEDING AND CURRENT ROW
    ) as moving_avg_4_orders,

    -- 5. ยอด order ก่อนหน้า
    LAG(amount, 1, 0) OVER (
        PARTITION BY customer_id
        ORDER BY order_date
    ) as previous_order,

    -- 6. ยอด order ถัดไป
    LEAD(amount, 1, 0) OVER (
        PARTITION BY customer_id
        ORDER BY order_date
    ) as next_order,

    -- 7. ยอด order แรกของลูกค้า
    FIRST_VALUE(amount) OVER (
        PARTITION BY customer_id
        ORDER BY order_date
    ) as first_order_amount

FROM enriched_orders
ORDER BY customer_id, order_date;
"""

window_analysis = con.execute(query).fetchdf()

# %%
window_analysis = con.execute(query).fetchdf()

# %%
window_analysis.head()
# Out:
#   order_id customer_id customer_name order_date  amount  order_sequence  \
# 0    O1001        C001      John Doe 2024-01-15   120.5               1
# 1    O1002        C001      John Doe 2024-02-20    75.0               2
# 2    O1003        C001      John Doe 2024-03-05    50.0               3
# 3    O1004        C002    Jane Smith 2024-04-25   200.0               1
# 4    O1005        C002    Jane Smith 2024-05-01   150.0               2
#
#    monthly_sales_rank  running_total  moving_avg_4_orders  previous_order  \
# 0                   1          120.5           120.500000             0.0
# 1                   1          195.5            97.750000           120.5
# 2                   1          245.5            81.833333            75.0
# 3                   1          200.0           200.000000             0.0
# 4                   1          350.0           175.000000           200.0
#
#    next_order  first_order_amount
# 0        75.0               120.5
# 1        50.0               120.5
# 2         0.0               120.5
# 3       150.0               200.0
# 4         0.0               200.0
